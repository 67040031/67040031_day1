# %%
# write a phython command for showing "hello world"
print ("hello world")
# Out:
# hello world

# %%
#using print fuction to show "hello world" and "good morning" for two lines
print ("hello world")
print ("good morning")
# Out:
# hello world
# good morning

# %%
#using print fuction to show "hello world" and "good morning" for two lines
print ("hello world" ,end=" ")
print ("good morning")
# Out:
# hello world good morning

# %%
print ("1")
print ("22")
print ("333")
print ("4444")
print ("55555")
print ("666666")
print ("7777777")
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
